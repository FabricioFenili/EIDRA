# %% [markdown]
# # Research Notebook Template\n\n## Purpose\nDocument a governed experiment from dataset version to decision outcome.\n\n## Mandatory fields\n- hypothesis\n- dataset version\n- feature version\n- target variable\n- model class\n- evaluation metric\n- conclusion\n

# %%
HYPOTHESIS = 'Define the research hypothesis here'\nDATASET_VERSION = 'v0'\nFEATURE_VERSION = 'v0'\nTARGET_VARIABLE = 'usd_brl_log_return'\nMODEL_CLASS = 'baseline'\n
